# %% [markdown]
# <h1>4. Applying ResNet pre-trained model </h1>

# %% [markdown]
# * We will not include the top layer of ResNet model.
# * Instead of top layer, we will add a dense layer with four units and with softmax activation function.
# * We will take the imagenet weight as weight initialization and will not freeze any layer.

# %%
import os
from glob import glob
import pandas as pd
import numpy as np
from numpy import expand_dims
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sn
from skimage.transform import resize
from skimage.color import gray2rgb
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from IPython.display import SVG

from tensorflow import keras
from tensorflow.keras import applications, optimizers
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.layers import Dense, Flatten, Dropout, Input
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.utils import to_categorical, model_to_dot, plot_model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau

# %%
data_dir = './tcga_coad_msi_mss/'
train_data_dir= './tcga_coad_msi_mss/train'
val_data_dir= './tcga_coad_msi_mss/val'
test_data_dir= './tcga_coad_msi_mss/test'

img_width, img_height = 150, 150 
channels = 3
batch_size = 32

# %%
train_datagen = ImageDataGenerator(
    rescale= 1./255,
    zoom_range= (0.73, 0.9),
    horizontal_flip= True,
    rotation_range= 10,
    width_shift_range= 0.10,
    fill_mode= 'constant',
    height_shift_range= 0.10,   
    brightness_range= (0.55, 0.9),
)

valid_test_datagen = ImageDataGenerator(
    rescale= 1./255, 
)

# %%
train_generator = train_datagen.flow_from_directory(  
    train_data_dir,  
    target_size= (img_width, img_height), 
    color_mode= 'rgb',
    batch_size= batch_size,  
    class_mode= 'categorical',
    shuffle= True, 
    seed= 1337
)

valid_generator = valid_test_datagen.flow_from_directory(
    val_data_dir,
    target_size= (img_width, img_height),
    color_mode= 'rgb',
    batch_size= batch_size,  
    class_mode= 'categorical',
    shuffle= True, 
    seed= 1337
)

test_generator = valid_test_datagen.flow_from_directory(  
    test_data_dir,  
    target_size= (img_width, img_height), 
    color_mode= 'rgb',
    batch_size= batch_size,        
    class_mode= 'categorical',
    shuffle= False, 
)
# Out:
# Found 153849 images belonging to 2 classes.
# Found 19230 images belonging to 2 classes.
# Found 19233 images belonging to 2 classes.

# %%
labels = os.listdir('./tcga_coad_msi_mss/train');
t_x, t_y = next(train_generator)
fig, m_axs = plt.subplots(4, 4, figsize = (16, 16))
for (c_x, c_y, c_ax) in zip(t_x, t_y, m_axs.flatten()):
    c_ax.imshow(c_x[:,:,0], cmap = 'bone')
    c_ax.set_title(', '.join([n_class for n_class, n_score in zip(labels, c_y) 
                             if n_score>0.5]))
    c_ax.axis('off')

# %%
num_classes = len(train_generator.class_indices)  
train_labels = train_generator.classes 
train_labels = to_categorical(train_labels, num_classes=num_classes)
valid_labels = valid_generator.classes 
valid_labels = to_categorical(valid_labels, num_classes=num_classes)
nb_train_samples = len(train_generator.filenames)  
nb_valid_samples = len(valid_generator.filenames)
nb_test_samples = len(test_generator.filenames)

# %%
# Defining ResNet model
def resnet_model():
    img_in = Input(t_x.shape[1:])              #input of model 
    model = ResNet50(include_top= False , # remove  the 3 fully-connected layers at the top of the network
                weights='imagenet',      # pre train weight 
                input_tensor= img_in, 
                input_shape= t_x.shape[1:],
                pooling ='avg') 
    x = model.output
    x = (Flatten(input_shape= (4, 4, 512)))(x)
    x = (Dropout(0.2))(x)
    predictions = Dense(4, activation="softmax", name="predictions")(x)    # fuly connected layer for predict class 
    model = Model(inputs=img_in, outputs=predictions)
    return model

# %%
# compiling model
model = resnet_model()
model.compile(optimizer = keras.optimizers.Adam(1e-5), loss = 'categorical_crossentropy',
                           metrics = ['accuracy'])

# %%
# creating checkpoint
filepath="weights_resnet_viva.hdf5"
checkpoint = ModelCheckpoint(
    filepath, 
    monitor='val_accuracy', 
    verbose=1, 
    save_best_only=True, 
    mode='max')

# callbacks_list = [checkpoint]

# %%
# training model
history = model.fit_generator(train_generator, 
                             steps_per_epoch=nb_train_samples//batch_size,
                             validation_data = valid_generator,
                             validation_steps = nb_valid_samples//batch_size,
                             epochs = 25,
                             verbose = 1,
                             callbacks=[checkpoint],
                             shuffle = True
                             )
# Out:
# WARNING:tensorflow:From <ipython-input-10-0b09560199af>:9: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 2609 steps, validate for 1 steps
# Epoch 1/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.3511 - accuracy: 0.8767
# Epoch 00001: val_accuracy improved from -inf to 0.93750, saving model to weights_resnet_viva.hdf5
# 2609/2609 [==============================] - 856s 328ms/step - loss: 0.3511 - accuracy: 0.8767 - val_loss: 0.1683 - val_accuracy: 0.9375
# Epoch 2/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.1943 - accuracy: 0.9341
# Epoch 00002: val_accuracy improved from 0.93750 to 0.96875, saving model to weights_resnet_viva.hdf5
# 2609/2609 [==============================] - 843s 323ms/step - loss: 0.1943 - accuracy: 0.9341 - val_loss: 0.0988 - val_accuracy: 0.9688
# Epoch 3/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.1579 - accuracy: 0.9460
# Epoch 00003: val_accuracy did not improve from 0.96875
# 2609/2609 [==============================] - 842s 323ms/step - loss: 0.1579 - accuracy: 0.9460 - val_loss: 0.0571 - val_accuracy: 0.9688
# Epoch 4/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.1356 - accuracy: 0.9532
# Epoch 00004: val_accuracy did not improve from 0.96875
# 2609/2609 [==============================] - 842s 323ms/step - loss: 0.1356 - accuracy: 0.9532 - val_loss: 0.0574 - val_accuracy: 0.9688
# Epoch 5/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.1226 - accuracy: 0.9583
# Epoch 00005: val_accuracy did not improve from 0.96875
# 2609/2609 [==============================] - 842s 323ms/step - loss: 0.1226 - accuracy: 0.9583 - val_loss: 0.0658 - val_accuracy: 0.9688
# Epoch 6/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.1126 - accuracy: 0.9618
# Epoch 00006: val_accuracy improved from 0.96875 to 1.00000, saving model to weights_resnet_viva.hdf5
# 2609/2609 [==============================] - 843s 323ms/step - loss: 0.1126 - accuracy: 0.9618 - val_loss: 0.0306 - val_accuracy: 1.0000
# Epoch 7/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.1032 - accuracy: 0.9635
# Epoch 00007: val_accuracy did not improve from 1.00000
# 2609/2609 [==============================] - 842s 323ms/step - loss: 0.1032 - accuracy: 0.9636 - val_loss: 0.0505 - val_accuracy: 0.9688
# Epoch 8/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.0936 - accuracy: 0.9676
# Epoch 00008: val_accuracy did not improve from 1.00000
# 2609/2609 [==============================] - 842s 323ms/step - loss: 0.0936 - accuracy: 0.9676 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 9/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.0870 - accuracy: 0.9693
# Epoch 00009: val_accuracy did not improve from 1.00000
# 2609/2609 [==============================] - 841s 322ms/step - loss: 0.0870 - accuracy: 0.9693 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 10/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.0819 - accuracy: 0.9710
# Epoch 00010: val_accuracy did not improve from 1.00000
# 2609/2609 [==============================] - 841s 322ms/step - loss: 0.0819 - accuracy: 0.9710 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 11/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.0768 - accuracy: 0.9737
# Epoch 00011: val_accuracy did not improve from 1.00000
# 2609/2609 [==============================] - 841s 322ms/step - loss: 0.0768 - accuracy: 0.9737 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 12/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.0711 - accuracy: 0.9745
# Epoch 00012: val_accuracy did not improve from 1.00000
# 2609/2609 [==============================] - 841s 322ms/step - loss: 0.0711 - accuracy: 0.9745 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 13/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.0683 - accuracy: 0.9764
# Epoch 00013: val_accuracy did not improve from 1.00000
# 2609/2609 [==============================] - 841s 322ms/step - loss: 0.0683 - accuracy: 0.9764 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 14/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.0640 - accuracy: 0.9774
# Epoch 00014: val_accuracy did not improve from 1.00000
# 2609/2609 [==============================] - 841s 322ms/step - loss: 0.0639 - accuracy: 0.9774 - val_loss: 0.0186 - val_accuracy: 1.0000
# Epoch 15/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.0596 - accuracy: 0.9788
# Epoch 00015: val_accuracy did not improve from 1.00000
# 2609/2609 [==============================] - 841s 322ms/step - loss: 0.0596 - accuracy: 0.9788 - val_loss: 0.0455 - val_accuracy: 0.9688
# Epoch 16/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.0571 - accuracy: 0.9793
# Epoch 00016: val_accuracy did not improve from 1.00000
# 2609/2609 [==============================] - 841s 322ms/step - loss: 0.0571 - accuracy: 0.9793 - val_loss: 0.0870 - val_accuracy: 0.9688
# Epoch 17/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.0529 - accuracy: 0.9807
# Epoch 00017: val_accuracy did not improve from 1.00000
# 2609/2609 [==============================] - 841s 322ms/step - loss: 0.0529 - accuracy: 0.9807 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 18/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.0514 - accuracy: 0.9813
# Epoch 00018: val_accuracy did not improve from 1.00000
# 2609/2609 [==============================] - 841s 322ms/step - loss: 0.0514 - accuracy: 0.9813 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 19/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.0471 - accuracy: 0.9833
# Epoch 00019: val_accuracy did not improve from 1.00000
# 2609/2609 [==============================] - 841s 322ms/step - loss: 0.0470 - accuracy: 0.9833 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 20/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.0455 - accuracy: 0.9835
# Epoch 00020: val_accuracy did not improve from 1.00000
# 2609/2609 [==============================] - 840s 322ms/step - loss: 0.0455 - accuracy: 0.9835 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 21/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.0438 - accuracy: 0.9844
# Epoch 00021: val_accuracy did not improve from 1.00000
# 2609/2609 [==============================] - 840s 322ms/step - loss: 0.0438 - accuracy: 0.9844 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 22/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.0398 - accuracy: 0.9852
# Epoch 00022: val_accuracy did not improve from 1.00000
# 2609/2609 [==============================] - 840s 322ms/step - loss: 0.0398 - accuracy: 0.9852 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 23/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.0382 - accuracy: 0.9862
# Epoch 00023: val_accuracy did not improve from 1.00000
# 2609/2609 [==============================] - 841s 322ms/step - loss: 0.0381 - accuracy: 0.9862 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 24/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.0376 - accuracy: 0.9866
# Epoch 00024: val_accuracy did not improve from 1.00000
# 2609/2609 [==============================] - 840s 322ms/step - loss: 0.0376 - accuracy: 0.9866 - val_loss: 0.0859 - val_accuracy: 0.9688
# Epoch 25/25
# 2608/2609 [============================>.] - ETA: 0s - loss: 0.0348 - accuracy: 0.9873
# Epoch 00025: val_accuracy did not improve from 1.00000
# 2609/2609 [==============================] - 841s 322ms/step - loss: 0.0348 - accuracy: 0.9873 - val_loss: 0.0142 - val_accuracy: 1.0000

# %%
filepath = 'weights_resnet_viva.hdf5'
# loading the model with best weight
model = resnet_model()
model.load_weights(filepath)

# %%
# creating test data
test_X, test_Y = next(valid_test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(150 , 150),
    batch_size=32,
    class_mode='categorical'))
# Out:
# Found 968 images belonging to 4 classes.

# %%
# predicting y value
y_pred = model.predict(test_X)

# %%
pred_class = []
for i in range(len(y_pred)):
    pred_class.append(np.argmax(y_pred[i]))

# %%
actual_class = []
for i in range(len(test_Y)):
    actual_class.append(np.argmax(test_Y[i]))

# %%
# accuracy score
from sklearn.metrics import accuracy_score
print('accuracy = ',accuracy_score(pred_class,actual_class))
# Out:
# accuracy =  0.96875

# %%
# defining confusion matrix
import seaborn as sns
from sklearn.metrics import confusion_matrix
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    
    labels = [0,1,2,3]
    # representing A in heatmap format
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    # representing B in heatmap format
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
plot_confusion_matrix(actual_class,pred_class)
# Out:
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
test_generator = valid_test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(150 , 150),
    batch_size=32,
    class_mode='categorical')
# Out:
# Found 968 images belonging to 4 classes.
